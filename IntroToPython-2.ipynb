# %% [markdown]
# Intro To Python

# %% [markdown]
# Print "Hello World!"

# %% [markdown]
# Data Types:

# %% [markdown]
# Create a variable with your name (string) eg. Shady

# %% [markdown]
# Create a variable with your height in meters (float) eg. 1.75

# %% [markdown]
# Create a variable with your age (integer) eg. 20

# %% [markdown]
# Create a variable stating if it is true or false that you have white socks (boolean) eg. True

# %% [markdown]
# Print "Hi, my name is x, I am x meters tall and am x years old."

# %% [markdown]
# Write an if statement that subtracts 1 from a number (x) if it's a multiple of 5

# %% [markdown]
# Print x

# %% [markdown]
# Write an if-else statement that subtracts one from a number if it's a multiple of 2 and you have white socks. Otherwise add one.

# %% [markdown]
# Ask for someone's age as input, store it in a variable. Write an if-else statement that checks if they are at least 20 years old.

# %% [markdown]
# Take the height and base of a triangle as input. Calculate and output the area.

# %% [markdown]
# Extra: Write some longer if-else statements.
